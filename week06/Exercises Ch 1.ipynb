# %% [markdown]
# _Exercises_: NLPP1e Chapter 1 (the stuff that might be due in an upcoming assignment).
# http://www.nltk.org/book/ch01.html
#
# The following exercises from Chapter 1 are what might be due in an assignment later on.

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# - Try out the concordance method, using another text and a word of your own choosing.

# %%
text6.concordance("man")
# Out:
# Displaying 24 of 24 matches:
# stops ] ARTHUR : Old woman ! DENNIS : Man ! ARTHUR : Man . Sorry . What knight
# : Old woman ! DENNIS : Man ! ARTHUR : Man . Sorry . What knight live in that ca
# UR : Well , I can ' t just call you ' Man '. DENNIS : Well , you could say ' De
#  aside ! BLACK KNIGHT : I move for no man . ARTHUR : So be it ! ARTHUR and BLAC
# ble . It ' s a busy life in Camelot . MAN : I have to push the pram a lot [ out
# on . ARTHUR : Now look here , my good man -- FRENCH GUARD : I don ' t wanna tal
#  t just a string of pussy jokes . OLD MAN : Get on with it . TIM THE ENCHANTER
# ear a starling -- oooh SCENE 12 : OLD MAN : Heh , hee ha ha hee hee ! Hee hee h
# u speak , he has seen the Grail ? OLD MAN : ... Ha ha ha ha ! Heh , hee ha ha h
# ... ARTHUR : Where does he live ? OLD MAN : ... Heh heh heh heh ... ARTHUR : Ol
#  ... Heh heh heh heh ... ARTHUR : Old man , where does he live ? OLD MAN : ...
# ...

# %%
text9.concordance("man")
# Out:
# Displaying 25 of 25 matches:
#  Man Who Was Thursday by G . K . Chesterto
# as nevertheless artistic . That young man with the long , auburn hair and the i
# r and the impudent face -- that young man was not really a poet ; but surely he
#  a frail but finished work of art . A man who stepped into its social atmospher
# these new women would always pay to a man the extravagant compliment which no o
# poet , was really ( in some sense ) a man worth listening to , even if one only
# ht you appeared in this garden ." The man with the meek blue eyes and the pale
# ere . An anarchist is an artist . The man who throws a bomb is an artist , beca
# o miss it . We feel it is epical when man with one wild arrow strikes a distant
# ant bird . Is it not also epical when man with one wild engine strikes a distan
#  , to Baker Street or to Bagdad . But man is a magician , and his whole magic i
# ron , who commemorates the defeats of man ; give me Bradshaw , who commemorates
# ...

# %% [markdown]
# - Also try out the similar and common_context methods for a few of your own examples.

# %%
text9.common_contexts(["boy", "man"])
# Out:
# a_. old_,

# %% [markdown]
# - Create your own version of a dispersion plot ("your own version" means another text and different word).

# %%
text9.dispersion_plot(["man", "Monday", "Tuesday", "Wednesday","Thursday", "Friday", "Saturday", "Sunday"])

# %% [markdown]
# - Explain in your own words what aspect of language lexical diversity describes.

# %% [markdown]
# Lexical diversity describes lexical richness. Shows that the author has a large vocabulary. The more synonyms used in the text, the less occurrences, hence, the dispersion plot will be less loaded.

# %% [markdown]
# - Create frequency distributions for text2, including the cumulative frequency plot for the 75 most common words.

# %%
freqDist2 = FreqDist(text2)
freqDist2.most_common(75)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461),
#  ('been', 440),
#  ('were', 437),
#  ('me', 433),
#  ('they', 428),
#  ('more', 406),
#  ('said', 397),
#  (',"', 396),
#  ('any', 389),
# ...

# %%
freqDist2.plot(75, cumulative=True)

# %% [markdown]
# - What is a bigram? How does it relate to collocations. Explain in your own words.
#
# A bigram is a pair of consecutive letters, syllables or words. It is related to collocations since some words are often put together. Not only because of a poor lexic, it can be intentional to provoke an association of two concepts in the reader.

# %% [markdown]
# # 1.8 Exercises

# %% [markdown]
# ## Ex 2 to 12 in NLPP's section 1.8.

# %% [markdown]
# 2. Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376L (the L at the end just indicates that this is Python's long-number format). How many hundred-letter strings are possible?

# %%
import numpy

# %%
#numpy.power(26, 100)
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# - numpy.power(26,100) was not giving any result, it returned '0'.

# %% [markdown]
# 3. The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] \* 20, or 3 \* sent1?

# %%
['Monty', 'Python'] * 20
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %%
print(sent1)
3 * sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %% [markdown]
# 4. Review 1.1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
totalWords = len(text2)
distinctWords = len(set(text2))
print("There is a total of %s words in text2, but its vocabulary is %s." % (totalWords, distinctWords))
# Out:
# There is a total of 141576 words in text2, but its vocabulary is 6833.

# %% [markdown]
# 5. Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?

# %%
print(text2, len(set(text2)))
print(text6, len(set(text6)))
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811> 6833
# <Text: Monty Python and the Holy Grail> 2166

# %% [markdown]
# 6. Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(["Elinor","Marianne", "Edward", "Willoughby"])

# %% [markdown]
# * From the plot we can read that female charachters have a more significant role in the book. They are mentioned more often and from beginnig to end. While male characters are intermitent.
#
# * Couples are Marianne and Willoughby, and Elinor and Edward

# %% [markdown]
# 7. Find the collocations in text5.

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# 8. Consider the following Python expression: len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.

# %%
len(set(text4))
# Out:
# 9754

# %% [markdown]
# * First, you take all the words in the given text (i.e. text4) and create a set. The type _set_ is a list that avoids repetitions.
# * Measuring the length of the set (_len(set(...))_), we get the amount of distinct words in the given text.

# %% [markdown]
# 9. Review 1.2 on lists and strings.
#
#     * Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement.

# %%
mcdo = 'Old McDonald had a farm but he lost in a poker game.'
mcdo
# Out:
# 'Old McDonald had a farm but he lost in a poker game.'

# %%
print(mcdo)
# Out:
# Old McDonald had a farm but he lost in a poker game.

# %% [markdown]
# * Try adding the string to itself using my_string + my_string, or multiplying it by a number, e.g., my_string * 3. Notice that the strings are joined together without any spaces. How could you fix this?

# %%
mcdo + mcdo
# Out:
# 'Old McDonald had a farm but he lost in a poker game.Old McDonald had a farm but he lost in a poker game.'

# %%
mcdo * 3
# Out:
# 'Old McDonald had a farm but he lost in a poker game.Old McDonald had a farm but he lost in a poker game.Old McDonald had a farm but he lost in a poker game.'

# %% [markdown]
#   - By simply adding the space:

# %%
(mcdo + ' ') * 2
# Out:
# 'Old McDonald had a farm but he lost in a poker game. Old McDonald had a farm but he lost in a poker game. '

# %% [markdown]
# 10. Define a variable my_sent to be a list of words, using the syntax my_sent = ["My", "sent"] (but with your own words, or a favorite saying).

# %%
my_sent = ['Always', 'look' ,'on', 'the', 'bright', 'side', 'of', 'life']

# %% [markdown]
# - Use ' '.join(my_sent) to convert this into a string.
# - Use split() to split the string back into the list form you had to start with.

# %%
' '.join(my_sent)
# Out:
# 'Always look on the bright side of life'

# %%
' '.join(my_sent).split()
# Out:
# ['Always', 'look', 'on', 'the', 'bright', 'side', 'of', 'life']

# %% [markdown]
# 11. Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?

# %%
s15 = sent1 + sent5
s14 = sent1 + sent4
s45 = sent4 + sent5

# %%
len(s15)
# Out:
# 15

# %%
len(sent1) + len(sent5)
# Out:
# 15

# %% [markdown]
# - They are counting words, so id doesn't matter in this operation if you cont separately or once merged the sentences.

# %% [markdown]
# 12. Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?
#
#     * "Monty Python"[6:12]
#     * ["Monty", "Python"][1]

# %% [markdown]
# *
# I would say that the second one is more relevant since it selects a word, which is more natural than knowing beforehand where in char we can find the different characters of a word.

# %% [markdown]
# ### Ex. 15, 17, 19, 22, 23, 26, 27, 28 in section 1.8.

# %% [markdown]
# 15. Review the discussion of conditionals in 1.4. Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
wordsStartingWithB = list()
for word in text5:
    if word.startswith('b'):
        wordsStartingWithB.append(word)

# %%
sorted(set(wordsStartingWithB))
# Out:
# ['b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...

# %% [markdown]
# 16. Type the expression range(10) at the interpreter prompt. Now try range(10, 20), range(10, 20, 2), and range(20, 10, -2). We will see a variety of uses for this built-in function in later chapters.

# %%
range(20, 10, -2)
# Out:
# range(20, 10, -2)

# %% [markdown]
# 17. Use text9.index() to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9.index('sunset')
text9.concordance('sunset')
# Out:
# Displaying 14 of 14 matches:
# HE suburb of Saffron Park lay on the sunset side of London , as red and ragged a
# on , as red and ragged as a cloud of sunset . It was built of a bright brick thr
# mbered in that place for its strange sunset . It looked like the end of the worl
# rival ; it was upon the night of the sunset that his solitude suddenly ended . T
# the Embankment once under a dark red sunset . The red river reflected the red sk
# ost seemed of fiercer flame than the sunset it mirrored . It looked like a strea
# the passionate plumage of the cloudy sunset had been swept away , and a naked mo
# nder the sea . The sealed and sullen sunset behind the dark dome of St . Paul '
# rming with the colour and quality of sunset . The Colonel suggested that , befor
#  gold . Up this side street the last sunset light shone as sharp and narrow as t
#  of gas , which in the full flush of sunset seemed coloured like a sunset cloud
# ...

# %%
text9[621:644]
# Out:
# ['THE',
#  'suburb',
#  'of',
#  'Saffron',
#  'Park',
#  'lay',
#  'on',
#  'the',
#  'sunset',
#  'side',
#  'of',
#  'London',
#  ',',
#  'as',
#  'red',
#  'and',
#  'ragged',
#  'as',
#  'a',
#  'cloud',
#  'of',
#  'sunset',
#  '.']

# %% [markdown]
# 18. Using list addition, and the set and sorted operations, compute the vocabulary of the sentences sent1 ... sent8.

# %%
sorted(w.lower() for w in set(sent1 + sent2+ sent3 + sent4 + sent5 + sent6 + sent7 + sent8))
# Out:
# ['!',
#  ',',
#  '-',
#  '.',
#  '1',
#  '25',
#  '29',
#  '61',
#  ':',
#  '[',
#  ']',
#  'a',
#  'and',
#  'arthur',
#  'as',
#  'attrac',
#  'been',
#  'beginning',
#  'board',
#  'call',
#  'citizens',
#  'clop',
#  'created',
#  'dashwood',
#  'director',
#  'discreet',
#  'earth',
#  'encounters',
#  'family',
#  'fellow',
#  'for',
#  'god',
#  'had',
#  'have',
#  'heaven',
#  'house',
#  'i',
#  'in',
#  'in',
#  'ishmael',
#  'join',
#  'join',
#  'king',
#  'lady',
#  'lol',
#  'long',
#  'male',
#  'me',
#  'nonexecutive',
#  'nov.',
#  'of',
#  'old',
#  'older',
#  'people',
#  'pierre',
#  'pming',
#  'problem',
#  'representatives',
#  'scene',
#  'seeks',
#  'senate',
#  'settled',
#  'sexy',
#  'single',
#  'sussex',
#  'the',
#  'the',
#  'there',
#  'to',
#  'vinken',
#  'whoa',
#  'will',
#  'wind',
#  'with',
#  'years']

# %% [markdown]
# 19. What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?
#
# > sorted(set([w.lower() for w in text1]))
#
#
#
# > sorted([w.lower() for w in set(text1)])
#
# - The first one is slower. It takes all the words in the text regardless of repetition and then it removes the multiple occurrences. While the second line first takes the distinct words and then creates the set.

# %% [markdown]
# 22. Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
fourLetter = list()
for w in text5:
    if len(w) == 4:
        fourLetter.append(w)

# %%
fdFour = FreqDist(fourLetter)

# %%
fdFour.plot(len(fdFour), cumulative = True)

# %% [markdown]
# 23. Review the discussion of looping with conditions in 1.4. Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
for w in text6:
    if w.isupper():
        print(w)
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %% [markdown]
# 26. What does the following Python code do? sum([len(w) for w in text1]) Can you use it to work out the average word length of a text?

# %%
sum([len(w) for w in text1])
# Out:
# 999044

# %% [markdown]
# - Takes word by word text1.
# - Calculates its length.
# - Sums all the lengths.
# - If we divide by the number of words, we can easily calculate the average word length

# %%
sum([len(w) for w in text1])/len(text1)
# Out:
# 3.830411128023649

# %% [markdown]
# 27.  Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
def vocab_size(text):
    return len(set(text))

# %%
vocab_size(text2)
# Out:
# 6833

# %% [markdown]
# 28. Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word, text):
    fd = FreqDist(text)
    return fd[word]/len(text)*100

# %%
percent('Willoughby', text2)
# Out:
# 0.15186189749675086
